# %%
import nflreadpy as nfl
from data_manager import NflDataRepo, FfbData

# %%
seasons = [2020, 2021, 2022, 2023, 2024, 2025]
nfl_data = NflDataRepo(seasons)

# %%
list(nfl_data.get_player_gamelog("Chris Olave").columns)
# Out:
# ['player_id',
#  'player_name',
#  'player_display_name',
#  'position',
#  'position_group',
#  'headshot_url',
#  'season',
#  'week',
#  'season_type',
#  'team',
#  'opponent_team',
#  'completions',
#  'attempts',
#  'passing_yards',
#  'passing_tds',
#  'passing_interceptions',
#  'sacks_suffered',
#  'sack_yards_lost',
#  'sack_fumbles',
#  'sack_fumbles_lost',
#  'passing_air_yards',
#  'passing_yards_after_catch',
#  'passing_first_downs',
#  'passing_epa',
#  'passing_cpoe',
#  'passing_2pt_conversions',
#  'pacr',
#  'carries',
#  'rushing_yards',
#  'rushing_tds',
#  'rushing_fumbles',
#  'rushing_fumbles_lost',
#  'rushing_first_downs',
#  'rushing_epa',
#  'rushing_2pt_conversions',
#  'receptions',
#  'targets',
#  'receiving_yards',
#  'receiving_tds',
#  'receiving_fumbles',
#  'receiving_fumbles_lost',
#  'receiving_air_yards',
#  'receiving_yards_after_catch',
#  'receiving_first_downs',
#  'receiving_epa',
#  'receiving_2pt_conversions',
#  'racr',
# ...

# %%
ffb_data = FfbData()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ffb_data = FfbData()
#
# File ~/Desktop/DataHuddle/data_manager.py:8, in FfbData.__init__(self)
#       7 def __init__(self):
# ----> 8     self.qb_projections = read_collection("ffb_qb_projections")
#       9     self.flex_projections = read_collection("ffb_flex_projections")
#
# File ~/Desktop/DataHuddle/db/reader.py:7, in read_collection(collection_name)
#       6 def read_collection(collection_name):
# ----> 7     docs = list(get_db()[collection_name].find({}, {"_id": 0}))
#       8     return pd.DataFrame(docs)
#
# File ~/Desktop/DataHuddle/db/connection.py:16, in get_db()
#      15 def get_db():
# ---> 16     return get_client()["data-huddle"]
#
# File ~/Desktop/DataHuddle/db/connection.py:11, in get_client()
#       9 global _client
#      10 if _client is None:
# ...
